# %%
l1=[23,34,45,35,56,75]
c=0
max=int(input("enter the max range="))
min=int(input("enter the min range="))
for i in l1:
  if i>min and i<max:
      c+=1
  else:
      c
print(c)
# Out:
# enter the max range=60
# enter the min range=30
# 4

# %%
l1=['abc','xyz','aba','1121']
c=0;
for i in l1:
  if len(l1)>2:
    if i[0]==i[-1]:
      c+=1
    else:
      c
print(c)
# Out:
# 2

# %%
l1=['p1','p2']
n=int(input("enter n="))
l2=[]
l3=[]
for i in range(1,n+1):
  l2.append('p'+str(i))
  l3.append('q'+str(i))
l4=[]
j=0
k=0
for i in range(n*2):
  if i%2==0:
    l4.append(l2[j])
    j+=1
  else:
    l4.append(l3[k])
    k+=1
print(l4)
# Out:
# enter n=4
# ['p1', 'q1', 'p2', 'q2', 'p3', 'q3', 'p4', 'q4']

# %%
tuple=(1,2,3)
 
for i in tuple:
# Out:
#   File "<ipython-input-41-8e11cdc05565>", line 4
#     str(tuple)+=str(tuple)
#     ^
# SyntaxError: can't assign to function call

# %%
tuple=((10,10,10,12),(30,45,56,23),(23,34,21,97,56),(1,2,3,4))
t1=()
for i in zip(*tuple):
  t1=(sum(i)/len(i))
  print(t1)
# Out:
# 16.0
# 22.75
# 22.5
# 34.0
